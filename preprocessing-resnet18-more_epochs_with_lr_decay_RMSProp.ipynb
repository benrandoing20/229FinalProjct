# %% [markdown]
# # 2 Layer Neural Network

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd

# %% [markdown]
# ## Import data and create .csv

# %%
# Directory to MRI Images
base_dir = '/Users/benrandoing/Downloads/archive/AugmentedAlzheimerDataset'
classes = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

if not os.path.exists('dataset.csv'):
    data = []

    for label, class_name in enumerate(classes):
        class_dir = os.path.join(base_dir, class_name)
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            data.append([image_path, label])

    df = pd.DataFrame(data, columns=['path', 'label'])
    df.to_csv('dataset.csv', index=False)

# %% [markdown]
# ## Data Loading and Pre-Processing

# %%
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.dataframe = pd.read_csv(csv_file)
        self.dataframe = self.dataframe.sample(frac=1).reset_index(drop=True)  # Shuffle the dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        image = Image.open(img_name)
        label = int(self.dataframe.iloc[idx, 1])

        if self.transform:
            image = self.transform(image)

        return image, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize image to 224 X 224
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    #transforms.Lambda(lambda x: x.view(-1))  # Flatten the image
])

# Load the entire dataset
dataset = CustomDataset(csv_file='dataset.csv', transform=transform)

# Split the dataset into train, validation, and test sets
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
print(f'Training Samples: {len(train_dataset)}')
print(f'Validation Samples: {len(val_dataset)}')
print(f'Test Samples: {len(test_dataset)}')
# Out:
# Training Samples: 23788
# Validation Samples: 5097
# Test Samples: 5099

# %%
print(train_dataset)
# Out:
# <torch.utils.data.dataset.Subset object at 0x7f9d1261b400>

# %%
import matplotlib.pyplot as plt
#plt.plot(train_dataset[0][0])
#plt.show()

# %% [markdown]
# ## Pytorch Logistic Regression Model

# %%
class FiveLayerNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, output_dim):
        super(FiveLayerNN, self).__init__()
        self.fc1 = torch.nn.Linear(input_dim, hidden_dim1)
        self.fc2 = torch.nn.Linear(hidden_dim1, hidden_dim2)
        self.fc3 = torch.nn.Linear(hidden_dim2, hidden_dim3)
        self.fc4 = torch.nn.Linear(hidden_dim3, hidden_dim4)
        self.fc5 = torch.nn.Linear(hidden_dim4, output_dim)

    def forward(self, x):
        #x = x.view(-1, 224 * 224 * 3)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = self.fc5(x)
        return x

input_dim = 224 * 224 * 3  # Assuming the images are RGB
hidden_dim1 = 512
hidden_dim2 = 256
hidden_dim3 = 128
hidden_dim4 = 64
output_dim = 4  # Four classes

#model = FiveLayerNN(input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, output_dim)
import torchvision
from torchvision.models import resnet18, ResNet18_Weights
model = torchvision.models.resnet18(weights=ResNet18_Weights.DEFAULT)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

model.fc = torch.nn.Linear(model.fc.in_features, output_dim)

# %% [markdown]
# ## Training Loop

# %%
learning_rate = 0.001
num_epochs = 20
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()

import torch.optim
optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)

#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)


# Training loop
for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0

    i = 0
    for inputs, labels in train_loader:
        i = i + 1
        print("Training continues..", total_loss, "current i = ", i)    
        optimizer.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)        
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    #lr decay
    #lr_scheduler.step()

    print(f"Iteration {epoch} - Loss = {total_loss / len(train_loader)}")
# Out:
# Training continues.. 0.0 current i =  1
# Training continues.. 1.4263499975204468 current i =  2
# Training continues.. 5.120266556739807 current i =  3
# Training continues.. 8.428125977516174 current i =  4
# Training continues.. 10.543232798576355 current i =  5
# Training continues.. 12.810245633125305 current i =  6
# Training continues.. 14.947182774543762 current i =  7
# Training continues.. 16.718878746032715 current i =  8
# Training continues.. 18.46541678905487 current i =  9
# Training continues.. 19.88349986076355 current i =  10
# Training continues.. 21.31885039806366 current i =  11
# Training continues.. 22.89302897453308 current i =  12
# Training continues.. 24.299073576927185 current i =  13
# Training continues.. 25.665361642837524 current i =  14
# Training continues.. 27.026344180107117 current i =  15
# Training continues.. 28.625990986824036 current i =  16
# Training continues.. 29.91148614883423 current i =  17
# Training continues.. 31.349323630332947 current i =  18
# Training continues.. 32.684818267822266 current i =  19
# Training continues.. 33.94433081150055 current i =  20
# Training continues.. 35.282649636268616 current i =  21
# Training continues.. 36.62208354473114 current i =  22
# Training continues.. 38.1105774641037 current i =  23
# Training continues.. 39.50014114379883 current i =  24
# Training continues.. 41.042516589164734 current i =  25
# Training continues.. 42.542362093925476 current i =  26
# Training continues.. 43.98803377151489 current i =  27
# Training continues.. 45.34406840801239 current i =  28
# Training continues.. 46.723389744758606 current i =  29
# Training continues.. 48.11379146575928 current i =  30
# Training continues.. 49.36117899417877 current i =  31
# Training continues.. 50.741947174072266 current i =  32
# Training continues.. 52.036176323890686 current i =  33
# Training continues.. 53.36080825328827 current i =  34
# Training continues.. 54.725879311561584 current i =  35
# Training continues.. 55.99444806575775 current i =  36
# Training continues.. 57.303637862205505 current i =  37
# Training continues.. 58.566620111465454 current i =  38
# Training continues.. 60.056997895240784 current i =  39
# Training continues.. 61.51653289794922 current i =  40
# Training continues.. 62.86014258861542 current i =  41
# Training continues.. 64.20151960849762 current i =  42
# Training continues.. 65.46236872673035 current i =  43
# Training continues.. 66.73507308959961 current i =  44
# Training continues.. 68.0489091873169 current i =  45
# Training continues.. 69.3829038143158 current i =  46
# Training continues.. 70.70044016838074 current i =  47
# Training continues.. 71.91795063018799 current i =  48
# Training continues.. 73.25263452529907 current i =  49
# Training continues.. 74.56582045555115 current i =  50
# Training continues.. 75.91647624969482 current i =  51
# Training continues.. 77.12515699863434 current i =  52
# Training continues.. 78.47688341140747 current i =  53
# Training continues.. 79.6569412946701 current i =  54
# Training continues.. 80.989497423172 current i =  55
# Training continues.. 82.1952269077301 current i =  56
# Training continues.. 83.35428285598755 current i =  57
# Training continues.. 84.7090550661087 current i =  58
# Training continues.. 86.01554334163666 current i =  59
# Training continues.. 87.42838406562805 current i =  60
# Training continues.. 88.72394275665283 current i =  61
# Training continues.. 90.08696663379669 current i =  62
# Training continues.. 91.43528628349304 current i =  63
# Training continues.. 92.75598526000977 current i =  64
# Training continues.. 93.90582370758057 current i =  65
# Training continues.. 95.04817962646484 current i =  66
# Training continues.. 96.09859299659729 current i =  67
# Training continues.. 97.26829898357391 current i =  68
# Training continues.. 98.46049070358276 current i =  69
# Training continues.. 99.85877811908722 current i =  70
# Training continues.. 101.10267102718353 current i =  71
# Training continues.. 102.25121819972992 current i =  72
# Training continues.. 103.37974059581757 current i =  73
# Training continues.. 104.69129979610443 current i =  74
# Training continues.. 105.93116641044617 current i =  75
# Training continues.. 107.12086200714111 current i =  76
# Training continues.. 108.3697212934494 current i =  77
# Training continues.. 109.47449743747711 current i =  78
# Training continues.. 110.92641842365265 current i =  79
# Training continues.. 112.18389308452606 current i =  80
# Training continues.. 113.29671144485474 current i =  81
# Training continues.. 114.65193521976471 current i =  82
# Training continues.. 115.77905142307281 current i =  83
# Training continues.. 117.01226079463959 current i =  84
# Training continues.. 118.39866411685944 current i =  85
# Training continues.. 119.6150484085083 current i =  86
# Training continues.. 120.74865818023682 current i =  87
# Training continues.. 121.79506242275238 current i =  88
# Training continues.. 122.86345529556274 current i =  89
# Training continues.. 123.97375047206879 current i =  90
# Training continues.. 125.12296891212463 current i =  91
# Training continues.. 126.24480926990509 current i =  92
# Training continues.. 127.44907176494598 current i =  93
# Training continues.. 128.3993700146675 current i =  94
# Training continues.. 129.53453296422958 current i =  95
# Training continues.. 130.63791531324387 current i =  96
# Training continues.. 131.82958287000656 current i =  97
# Training continues.. 132.9837026000023 current i =  98
# Training continues.. 134.01668900251389 current i =  99
# Training continues.. 134.96105802059174 current i =  100
# Training continues.. 136.10762703418732 current i =  101
# Training continues.. 137.43917679786682 current i =  102
# Training continues.. 138.56701624393463 current i =  103
# Training continues.. 139.55338031053543 current i =  104
# Training continues.. 140.58255642652512 current i =  105
# Training continues.. 141.513352394104 current i =  106
# Training continues.. 142.33128958940506 current i =  107
# Training continues.. 143.23076969385147 current i =  108
# Training continues.. 144.33912736177444 current i =  109
# Training continues.. 145.49386423826218 current i =  110
# Training continues.. 146.58086162805557 current i =  111
# Training continues.. 147.82931965589523 current i =  112
# Training continues.. 148.80058133602142 current i =  113
# Training continues.. 149.89870953559875 current i =  114
# Training continues.. 151.00222599506378 current i =  115
# Training continues.. 152.0757781267166 current i =  116
# Training continues.. 153.05232232809067 current i =  117
# Training continues.. 154.02156561613083 current i =  118
# Training continues.. 154.85938668251038 current i =  119
# Training continues.. 155.5554964542389 current i =  120
# Training continues.. 156.3996166586876 current i =  121
# Training continues.. 157.22368866205215 current i =  122
# Training continues.. 158.1933690905571 current i =  123
# Training continues.. 159.5863339304924 current i =  124
# Training continues.. 160.94461351633072 current i =  125
# Training continues.. 162.22097915410995 current i =  126
# Training continues.. 163.3596960902214 current i =  127
# Training continues.. 164.3331640958786 current i =  128
# Training continues.. 165.15827822685242 current i =  129
# Training continues.. 166.19104480743408 current i =  130
# Training continues.. 166.99934482574463 current i =  131
# Training continues.. 167.86364126205444 current i =  132
# Training continues.. 168.65694278478622 current i =  133
# Training continues.. 169.59162962436676 current i =  134
# Training continues.. 170.51416045427322 current i =  135
# Training continues.. 171.46367245912552 current i =  136
# Training continues.. 172.3272541165352 current i =  137
# Training continues.. 173.14418202638626 current i =  138
# Training continues.. 173.96206027269363 current i =  139
# Training continues.. 174.74685549736023 current i =  140
# Training continues.. 175.5552829504013 current i =  141
# Training continues.. 176.86866438388824 current i =  142
# Training continues.. 177.9975792169571 current i =  143
# Training continues.. 178.89537757635117 current i =  144
# Training continues.. 179.78811937570572 current i =  145
# Training continues.. 180.69970989227295 current i =  146
# Training continues.. 181.44577479362488 current i =  147
# Training continues.. 182.3339987397194 current i =  148
# Training continues.. 183.3124237060547 current i =  149
# Training continues.. 184.1912700533867 current i =  150
# Training continues.. 185.0742319226265 current i =  151
# Training continues.. 185.83030462265015 current i =  152
# Training continues.. 186.66683346033096 current i =  153
# Training continues.. 187.74933570623398 current i =  154
# Training continues.. 188.72585892677307 current i =  155
# Training continues.. 189.67435824871063 current i =  156
# Training continues.. 190.4920238852501 current i =  157
# Training continues.. 191.34994304180145 current i =  158
# Training continues.. 192.24146115779877 current i =  159
# Training continues.. 193.18362218141556 current i =  160
# Training continues.. 193.91529697179794 current i =  161
# Training continues.. 194.75204783678055 current i =  162
# Training continues.. 195.5033985376358 current i =  163
# Training continues.. 196.37418788671494 current i =  164
# Training continues.. 197.19197416305542 current i =  165
# Training continues.. 197.88320571184158 current i =  166
# Training continues.. 198.65486824512482 current i =  167
# Training continues.. 199.4222270846367 current i =  168
# Training continues.. 200.24670833349228 current i =  169
# Training continues.. 201.18237966299057 current i =  170
# Training continues.. 202.24324983358383 current i =  171
# Training continues.. 203.28021162748337 current i =  172
# Training continues.. 203.98914140462875 current i =  173
# Training continues.. 204.65313118696213 current i =  174
# Training continues.. 205.68085545301437 current i =  175
# Training continues.. 206.5938858985901 current i =  176
# Training continues.. 207.28077274560928 current i =  177
# Training continues.. 208.01633244752884 current i =  178
# Training continues.. 208.66809928417206 current i =  179
# Training continues.. 209.2956304550171 current i =  180
# Training continues.. 210.07392472028732 current i =  181
# Training continues.. 210.83287477493286 current i =  182
# Training continues.. 211.52504551410675 current i =  183
# Training continues.. 212.31095999479294 current i =  184
# Training continues.. 212.90259474515915 current i =  185
# Training continues.. 213.58325797319412 current i =  186
# Training continues.. 214.24993640184402 current i =  187
# Training continues.. 214.998108625412 current i =  188
# Training continues.. 215.86283588409424 current i =  189
# Training continues.. 216.69466429948807 current i =  190
# Training continues.. 217.319764316082 current i =  191
# Training continues.. 218.09890282154083 current i =  192
# Training continues.. 218.81728595495224 current i =  193
# Training continues.. 219.48418527841568 current i =  194
# Training continues.. 220.12350696325302 current i =  195
# Training continues.. 220.74708265066147 current i =  196
# Training continues.. 221.46129423379898 current i =  197
# Training continues.. 222.1743773818016 current i =  198
# Training continues.. 222.77286368608475 current i =  199
# Training continues.. 223.56344306468964 current i =  200
# Training continues.. 224.37354040145874 current i =  201
# Training continues.. 225.20360738039017 current i =  202
# Training continues.. 226.07629883289337 current i =  203
# Training continues.. 226.80680656433105 current i =  204
# Training continues.. 227.52152758836746 current i =  205
# Training continues.. 228.2853708267212 current i =  206
# Training continues.. 228.98190832138062 current i =  207
# Training continues.. 230.01626229286194 current i =  208
# Training continues.. 230.8131104707718 current i =  209
# Training continues.. 231.69750106334686 current i =  210
# Training continues.. 232.37274038791656 current i =  211
# Training continues.. 233.07913959026337 current i =  212
# Training continues.. 233.79482108354568 current i =  213
# Training continues.. 234.51139706373215 current i =  214
# Training continues.. 235.2220600247383 current i =  215
# Training continues.. 235.90122139453888 current i =  216
# Training continues.. 236.54459828138351 current i =  217
# Training continues.. 237.45782965421677 current i =  218
# Training continues.. 238.16812825202942 current i =  219
# Training continues.. 238.86965584754944 current i =  220
# Training continues.. 239.7382474541664 current i =  221
# Training continues.. 240.39612102508545 current i =  222
# Training continues.. 241.1986352801323 current i =  223
# Training continues.. 242.02042883634567 current i =  224
# Training continues.. 242.84104830026627 current i =  225
# Training continues.. 243.50468361377716 current i =  226
# Training continues.. 244.40803903341293 current i =  227
# Training continues.. 245.11580818891525 current i =  228
# Training continues.. 245.898621737957 current i =  229
# Training continues.. 246.55750167369843 current i =  230
# Training continues.. 247.28128761053085 current i =  231
# Training continues.. 247.93232065439224 current i =  232
# Training continues.. 248.552952170372 current i =  233
# Training continues.. 249.31150633096695 current i =  234
# Training continues.. 250.01278007030487 current i =  235
# Training continues.. 250.70283031463623 current i =  236
# Training continues.. 251.25405037403107 current i =  237
# Training continues.. 251.84420722723007 current i =  238
# Training continues.. 252.5759983062744 current i =  239
# Training continues.. 253.21500778198242 current i =  240
# Training continues.. 254.0645106434822 current i =  241
# Training continues.. 254.81692284345627 current i =  242
# Training continues.. 255.70516806840897 current i =  243
# Training continues.. 256.5905011296272 current i =  244
# Training continues.. 257.27520352602005 current i =  245
# Training continues.. 257.9070047736168 current i =  246
# Training continues.. 258.61891680955887 current i =  247
# Training continues.. 259.3174687027931 current i =  248
# Training continues.. 260.07720082998276 current i =  249
# Training continues.. 260.76740378141403 current i =  250
# Training continues.. 261.43627393245697 current i =  251
# Training continues.. 262.1866007447243 current i =  252
# Training continues.. 263.441279232502 current i =  253
# Training continues.. 264.67885702848434 current i =  254
# Training continues.. 265.6451314687729 current i =  255
# Training continues.. 266.3910081386566 current i =  256
# Training continues.. 267.07927256822586 current i =  257
# Training continues.. 267.79923129081726 current i =  258
# Training continues.. 268.4450550675392 current i =  259
# Training continues.. 269.1355278491974 current i =  260
# Training continues.. 269.96201157569885 current i =  261
# Training continues.. 270.7795904278755 current i =  262
# Training continues.. 271.47698974609375 current i =  263
# Training continues.. 272.2446246147156 current i =  264
# Training continues.. 272.90216851234436 current i =  265
# Training continues.. 273.7710490822792 current i =  266
# Training continues.. 274.72180593013763 current i =  267
# Training continues.. 275.49459010362625 current i =  268
# Training continues.. 276.25176614522934 current i =  269
# Training continues.. 277.0012009739876 current i =  270
# Training continues.. 277.6899297237396 current i =  271
# Training continues.. 278.33671855926514 current i =  272
# Training continues.. 279.00415045022964 current i =  273
# Training continues.. 279.6122987270355 current i =  274
# Training continues.. 280.19615215063095 current i =  275
# Training continues.. 280.78617894649506 current i =  276
# Training continues.. 281.38693356513977 current i =  277
# Training continues.. 282.0547045469284 current i =  278
# Training continues.. 282.65489506721497 current i =  279
# Training continues.. 283.2933173775673 current i =  280
# Training continues.. 284.0121223330498 current i =  281
# Training continues.. 284.842017352581 current i =  282
# Training continues.. 285.63322895765305 current i =  283
# Training continues.. 286.4717530012131 current i =  284
# Training continues.. 287.2384412884712 current i =  285
# Training continues.. 288.02050745487213 current i =  286
# Training continues.. 288.8742621541023 current i =  287
# Training continues.. 289.5369625687599 current i =  288
# Training continues.. 290.1757051348686 current i =  289
# Training continues.. 290.7923272848129 current i =  290
# Training continues.. 291.572691321373 current i =  291
# Training continues.. 292.59866654872894 current i =  292
# Training continues.. 293.1697075366974 current i =  293
# Training continues.. 293.7495861053467 current i =  294
# Training continues.. 294.48993796110153 current i =  295
# Training continues.. 295.14964908361435 current i =  296
# Training continues.. 295.76019990444183 current i =  297
# Training continues.. 296.57848542928696 current i =  298
# Training continues.. 297.3032215833664 current i =  299
# Training continues.. 297.9525447487831 current i =  300
# Training continues.. 298.73300701379776 current i =  301
# Training continues.. 299.307635307312 current i =  302
# Training continues.. 299.94731307029724 current i =  303
# Training continues.. 300.61159855127335 current i =  304
# Training continues.. 301.2545365691185 current i =  305
# Training continues.. 301.79890835285187 current i =  306
# Training continues.. 302.4129822254181 current i =  307
# Training continues.. 303.0713435411453 current i =  308
# Training continues.. 303.7832933664322 current i =  309
# Training continues.. 304.5155639052391 current i =  310
# Training continues.. 305.27224987745285 current i =  311
# Training continues.. 305.98906022310257 current i =  312
# Training continues.. 306.6586139202118 current i =  313
# Training continues.. 307.3835186958313 current i =  314
# Training continues.. 308.19132393598557 current i =  315
# Training continues.. 308.8318811058998 current i =  316
# Training continues.. 309.50837713479996 current i =  317
# Training continues.. 310.1797444820404 current i =  318
# Training continues.. 310.8052374124527 current i =  319
# Training continues.. 311.39867347478867 current i =  320
# Training continues.. 312.052805185318 current i =  321
# Training continues.. 312.56015807390213 current i =  322
# Training continues.. 313.16130566596985 current i =  323
# Training continues.. 313.7515088915825 current i =  324
# Training continues.. 314.318820476532 current i =  325
# Training continues.. 314.9621840119362 current i =  326
# Training continues.. 315.98154217004776 current i =  327
# Training continues.. 317.30822640657425 current i =  328
# Training continues.. 318.2147983908653 current i =  329
# Training continues.. 318.9872470498085 current i =  330
# Training continues.. 319.5511538386345 current i =  331
# Training continues.. 320.16175615787506 current i =  332
# Training continues.. 320.8487369418144 current i =  333
# Training continues.. 321.47082126140594 current i =  334
# Training continues.. 322.1797103881836 current i =  335
# Training continues.. 322.81984996795654 current i =  336
# Training continues.. 323.546814262867 current i =  337
# Training continues.. 324.2616214156151 current i =  338
# Training continues.. 324.9035548567772 current i =  339
# Training continues.. 325.50048846006393 current i =  340
# Training continues.. 326.0726115703583 current i =  341
# Training continues.. 326.7865324020386 current i =  342
# Training continues.. 327.32663959264755 current i =  343
# Training continues.. 328.0897163748741 current i =  344
# Training continues.. 328.71284234523773 current i =  345
# Training continues.. 329.39738523960114 current i =  346
# Training continues.. 329.99037343263626 current i =  347
# Training continues.. 330.47148001194 current i =  348
# Training continues.. 331.0485943555832 current i =  349
# Training continues.. 331.79845029115677 current i =  350
# Training continues.. 332.4239162802696 current i =  351
# Training continues.. 333.05253469944 current i =  352
# Training continues.. 333.80772602558136 current i =  353
# Training continues.. 334.53339129686356 current i =  354
# Training continues.. 335.2207562327385 current i =  355
# Training continues.. 335.83616775274277 current i =  356
# Training continues.. 336.4765557050705 current i =  357
# Training continues.. 337.08604538440704 current i =  358
# Training continues.. 337.6258627176285 current i =  359
# Training continues.. 338.29432541131973 current i =  360
# Training continues.. 338.953007042408 current i =  361
# Training continues.. 339.57447266578674 current i =  362
# Training continues.. 340.22784799337387 current i =  363
# Training continues.. 340.8609091639519 current i =  364
# Training continues.. 341.5485003590584 current i =  365
# Training continues.. 342.1135818362236 current i =  366
# Training continues.. 342.61723774671555 current i =  367
# Training continues.. 343.30488789081573 current i =  368
# Training continues.. 343.90472507476807 current i =  369
# Training continues.. 344.52988731861115 current i =  370
# Training continues.. 345.28872513771057 current i =  371
# Training continues.. 345.9478380680084 current i =  372
# Iteration 0 - Loss = 0.9313514413692618
# Training continues.. 0.0 current i =  1
# Training continues.. 0.6960409879684448 current i =  2
# Training continues.. 1.3033729195594788 current i =  3
# Training continues.. 1.892539143562317 current i =  4
# Training continues.. 2.384687602519989 current i =  5
# Training continues.. 2.950514495372772 current i =  6
# Training continues.. 3.4562028646469116 current i =  7
# Training continues.. 3.951062172651291 current i =  8
# Training continues.. 4.422522246837616 current i =  9
# Training continues.. 5.112419664859772 current i =  10
# Training continues.. 5.710157990455627 current i =  11
# Training continues.. 6.265200138092041 current i =  12
# Training continues.. 6.878312766551971 current i =  13
# Training continues.. 7.390228807926178 current i =  14
# Training continues.. 7.7844832837581635 current i =  15
# Training continues.. 8.348251849412918 current i =  16
# Training continues.. 8.79849624633789 current i =  17
# Training continues.. 9.412427723407745 current i =  18
# Training continues.. 10.103034913539886 current i =  19
# Training continues.. 10.653294920921326 current i =  20
# Training continues.. 11.245617866516113 current i =  21
# Training continues.. 11.88344419002533 current i =  22
# Training continues.. 12.423422992229462 current i =  23
# Training continues.. 12.87763112783432 current i =  24
# Training continues.. 13.347923964262009 current i =  25
# Training continues.. 13.930437415838242 current i =  26
# Training continues.. 14.597562044858932 current i =  27
# Training continues.. 15.330840080976486 current i =  28
# Training continues.. 15.947329193353653 current i =  29
# Training continues.. 16.663062125444412 current i =  30
# Training continues.. 17.297967463731766 current i =  31
# Training continues.. 17.93344810605049 current i =  32
# Training continues.. 18.505023032426834 current i =  33
# Training continues.. 19.031514555215836 current i =  34
# Training continues.. 19.529670864343643 current i =  35
# Training continues.. 20.16676452755928 current i =  36
# Training continues.. 20.758300095796585 current i =  37
# Training continues.. 21.402723520994186 current i =  38
# Training continues.. 22.05985739827156 current i =  39
# Training continues.. 22.504624217748642 current i =  40
# Training continues.. 23.138423889875412 current i =  41
# Training continues.. 23.676008194684982 current i =  42
# Training continues.. 24.375914365053177 current i =  43
# Training continues.. 25.02755096554756 current i =  44
# Training continues.. 25.58831736445427 current i =  45
# Training continues.. 26.25895270705223 current i =  46
# Training continues.. 26.88671436905861 current i =  47
# Training continues.. 27.434699088335037 current i =  48
# Training continues.. 27.98897895216942 current i =  49
# Training continues.. 28.648783057928085 current i =  50
# Training continues.. 29.112519472837448 current i =  51
# Training continues.. 29.79804030060768 current i =  52
# Training continues.. 30.293662816286087 current i =  53
# Training continues.. 30.80172410607338 current i =  54
# Training continues.. 31.31103566288948 current i =  55
# Training continues.. 31.970141261816025 current i =  56
# Training continues.. 32.53490921854973 current i =  57
# Training continues.. 32.93930408358574 current i =  58
# Training continues.. 33.57616052031517 current i =  59
# Training continues.. 34.22596147656441 current i =  60
# Training continues.. 34.79670777916908 current i =  61
# Training continues.. 35.35451087355614 current i =  62
# Training continues.. 35.82973703742027 current i =  63
# Training continues.. 36.3748217523098 current i =  64
# Training continues.. 36.94420400261879 current i =  65
# Training continues.. 37.37683817744255 current i =  66
# Training continues.. 38.1921007335186 current i =  67
# Training continues.. 38.845464676618576 current i =  68
# Training continues.. 39.36983558535576 current i =  69
# Training continues.. 39.80686354637146 current i =  70
# Training continues.. 40.23073253035545 current i =  71
# Training continues.. 40.67722341418266 current i =  72
# Training continues.. 41.22879698872566 current i =  73
# Training continues.. 41.916723161935806 current i =  74
# Training continues.. 42.74812349677086 current i =  75
# Training continues.. 43.442818373441696 current i =  76
# Training continues.. 44.3321273624897 current i =  77
# Training continues.. 44.98985508084297 current i =  78
# Training continues.. 45.601724058389664 current i =  79
# Training continues.. 46.10538312792778 current i =  80
# Training continues.. 46.56560042500496 current i =  81
# Training continues.. 47.22177121043205 current i =  82
# Training continues.. 47.85394695401192 current i =  83
# Training continues.. 48.31217882037163 current i =  84
# Training continues.. 48.79040586948395 current i =  85
# Training continues.. 49.44301116466522 current i =  86
# Training continues.. 49.972913324832916 current i =  87
# Training continues.. 50.531903982162476 current i =  88
# Training continues.. 51.01439127326012 current i =  89
# Training continues.. 51.48243519663811 current i =  90
# Training continues.. 51.994803458452225 current i =  91
# Training continues.. 52.58827021718025 current i =  92
# Training continues.. 53.26686695218086 current i =  93
# Training continues.. 53.810421139001846 current i =  94
# Training continues.. 54.36226645112038 current i =  95
# Training continues.. 54.83542957901955 current i =  96
# Training continues.. 55.345379680395126 current i =  97
# Training continues.. 55.79805991053581 current i =  98
# Training continues.. 56.377303034067154 current i =  99
# Training continues.. 56.94115677475929 current i =  100
# Training continues.. 57.515454322099686 current i =  101
# Training continues.. 57.91045477986336 current i =  102
# Training continues.. 58.38750496506691 current i =  103
# Training continues.. 59.01005908846855 current i =  104
# Training continues.. 59.40424171090126 current i =  105
# Training continues.. 60.02712085843086 current i =  106
# Training continues.. 60.472464472055435 current i =  107
# Training continues.. 60.927682280540466 current i =  108
# Training continues.. 61.47255980968475 current i =  109
# Training continues.. 61.96398043632507 current i =  110
# Training continues.. 62.517310321331024 current i =  111
# Training continues.. 63.018617391586304 current i =  112
# Training continues.. 63.463864862918854 current i =  113
# Training continues.. 64.04657137393951 current i =  114
# Training continues.. 64.53351274132729 current i =  115
# Training continues.. 65.21752813458443 current i =  116
# Training continues.. 65.7418507039547 current i =  117
# Training continues.. 66.20571687817574 current i =  118
# Training continues.. 66.79960748553276 current i =  119
# Training continues.. 67.25622671842575 current i =  120
# Training continues.. 67.66458833217621 current i =  121
# Training continues.. 68.11869242787361 current i =  122
# Training continues.. 68.55195820331573 current i =  123
# Training continues.. 69.18377023935318 current i =  124
# Training continues.. 69.87412816286087 current i =  125
# Training continues.. 70.2970420718193 current i =  126
# Training continues.. 70.71599519252777 current i =  127
# Training continues.. 71.21151581406593 current i =  128
# Training continues.. 71.71265605092049 current i =  129
# Training continues.. 72.36923304200172 current i =  130
# Training continues.. 72.88120558857918 current i =  131
# Training continues.. 73.44989570975304 current i =  132
# Training continues.. 73.89880982041359 current i =  133
# Training continues.. 74.35911351442337 current i =  134
# Training continues.. 74.87994915246964 current i =  135
# Training continues.. 75.43896406888962 current i =  136
# Training continues.. 75.87822633981705 current i =  137
# Training continues.. 76.37676227092743 current i =  138
# Training continues.. 76.95295250415802 current i =  139
# Training continues.. 77.36678954958916 current i =  140
# Training continues.. 77.68629536032677 current i =  141
# Training continues.. 78.20332172513008 current i =  142
# Training continues.. 78.79965540766716 current i =  143
# Training continues.. 79.4331126511097 current i =  144
# Training continues.. 79.94974038004875 current i =  145
# Training continues.. 80.45098647475243 current i =  146
# Training continues.. 80.88148882985115 current i =  147
# Training continues.. 81.26274290680885 current i =  148
# Training continues.. 81.89748147130013 current i =  149
# Training continues.. 82.26348999142647 current i =  150
# Training continues.. 82.53786981105804 current i =  151
# Training continues.. 82.95993596315384 current i =  152
# Training continues.. 83.58418774604797 current i =  153
# Training continues.. 83.95882192254066 current i =  154
# Training continues.. 84.3024870455265 current i =  155
# Training continues.. 84.59998658299446 current i =  156
# Training continues.. 84.96989661455154 current i =  157
# Training continues.. 85.408685952425 current i =  158
# Training continues.. 86.36729344725609 current i =  159
# Training continues.. 86.88513711094856 current i =  160
# Training continues.. 87.23567143082619 current i =  161
# Training continues.. 87.72689071297646 current i =  162
# Training continues.. 88.2184302508831 current i =  163
# Training continues.. 88.85696890950203 current i =  164
# Training continues.. 89.63397255539894 current i =  165
# Training continues.. 90.47102299332619 current i =  166
# Training continues.. 90.98117914795876 current i =  167
# Training continues.. 91.7608428299427 current i =  168
# Training continues.. 92.20649608969688 current i =  169
# Training continues.. 92.76157745718956 current i =  170
# Training continues.. 93.18951135873795 current i =  171
# Training continues.. 93.6530472934246 current i =  172
# Training continues.. 94.19859465956688 current i =  173
# Training continues.. 94.70191219449043 current i =  174
# Training continues.. 95.14317256212234 current i =  175
# Training continues.. 95.63422763347626 current i =  176
# Training continues.. 96.08800208568573 current i =  177
# Training continues.. 96.71758556365967 current i =  178
# Training continues.. 97.1415042579174 current i =  179
# Training continues.. 97.55044826865196 current i =  180
# Training continues.. 98.01238164305687 current i =  181
# Training continues.. 98.51146385073662 current i =  182
# Training continues.. 99.12977716326714 current i =  183
# Training continues.. 99.61519294977188 current i =  184
# Training continues.. 99.98991695046425 current i =  185
# Training continues.. 100.5179947912693 current i =  186
# Training continues.. 101.10083976387978 current i =  187
# Training continues.. 101.49164220690727 current i =  188
# Training continues.. 101.97927781939507 current i =  189
# Training continues.. 102.38374561071396 current i =  190
# Training continues.. 102.71907290816307 current i =  191
# Training continues.. 103.06403172016144 current i =  192
# Training continues.. 103.36923962831497 current i =  193
# Training continues.. 103.8227142393589 current i =  194
# Training continues.. 104.36865577101707 current i =  195
# Training continues.. 104.77154126763344 current i =  196
# Training continues.. 105.26794868707657 current i =  197
# Training continues.. 105.66966608166695 current i =  198
# Training continues.. 106.05296763777733 current i =  199
# Training continues.. 106.47296294569969 current i =  200
# Training continues.. 107.02521100640297 current i =  201
# Training continues.. 107.34820741415024 current i =  202
# Training continues.. 107.95029556751251 current i =  203
# Training continues.. 108.3937614262104 current i =  204
# Training continues.. 108.69748869538307 current i =  205
# Training continues.. 109.0506999194622 current i =  206
# Training continues.. 109.53822714090347 current i =  207
# Training continues.. 109.94709801673889 current i =  208
# Training continues.. 110.3587894141674 current i =  209
# Training continues.. 110.7297403216362 current i =  210
# Training continues.. 111.06483843922615 current i =  211
# Training continues.. 111.66124841570854 current i =  212
# Training continues.. 112.02313151955605 current i =  213
# Training continues.. 112.37941735982895 current i =  214
# Training continues.. 112.81260758638382 current i =  215
# Training continues.. 113.29497250914574 current i =  216
# Training continues.. 113.91010156273842 current i =  217
# Training continues.. 114.36842009425163 current i =  218
# Training continues.. 114.68945625424385 current i =  219
# Training continues.. 115.25883111357689 current i =  220
# Training continues.. 115.65998527407646 current i =  221
# Training continues.. 116.17230948805809 current i =  222
# Training continues.. 116.48448231816292 current i =  223
# Training continues.. 116.88683071732521 current i =  224
# Training continues.. 117.31376591324806 current i =  225
# Training continues.. 117.77589213848114 current i =  226
# Training continues.. 118.11076191067696 current i =  227
# Training continues.. 118.54855480790138 current i =  228
# Training continues.. 118.94482830166817 current i =  229
# Training continues.. 119.23791888356209 current i =  230
# Training continues.. 119.62017717957497 current i =  231
# Training continues.. 120.04772049188614 current i =  232
# Training continues.. 120.6078109741211 current i =  233
# Training continues.. 121.06726524233818 current i =  234
# Training continues.. 121.57868781685829 current i =  235
# Training continues.. 121.94129368662834 current i =  236
# Training continues.. 122.37247636914253 current i =  237
# Training continues.. 122.7159116268158 current i =  238
# Training continues.. 123.22676289081573 current i =  239
# Training continues.. 123.64365243911743 current i =  240
# Training continues.. 124.01529887318611 current i =  241
# Training continues.. 124.42601758241653 current i =  242
# Training continues.. 124.8168135881424 current i =  243
# Training continues.. 125.2502878010273 current i =  244
# Training continues.. 125.77369371056557 current i =  245
# Training continues.. 126.15153279900551 current i =  246
# Training continues.. 126.56428843736649 current i =  247
# Training continues.. 126.96830582618713 current i =  248
# Training continues.. 127.28464275598526 current i =  249
# Training continues.. 127.64540675282478 current i =  250
# Training continues.. 128.07051461935043 current i =  251
# Training continues.. 128.4653646349907 current i =  252
# Training continues.. 128.73382553458214 current i =  253
# Training continues.. 129.07006201148033 current i =  254
# Training continues.. 129.39738968014717 current i =  255
# Training continues.. 129.7835150361061 current i =  256
# Training continues.. 130.32648646831512 current i =  257
# Training continues.. 130.79770627617836 current i =  258
# Training continues.. 131.24586269259453 current i =  259
# Training continues.. 131.62995144724846 current i =  260
# Training continues.. 132.04162073135376 current i =  261
# Training continues.. 132.34154170751572 current i =  262
# Training continues.. 132.81661796569824 current i =  263
# Training continues.. 133.1800225675106 current i =  264
# Training continues.. 133.68225893378258 current i =  265
# Training continues.. 134.13685455918312 current i =  266
# Training continues.. 134.52699154615402 current i =  267
# Training continues.. 134.91623654961586 current i =  268
# Training continues.. 135.47124400734901 current i =  269
# Training continues.. 135.91626304388046 current i =  270
# Training continues.. 136.26699635386467 current i =  271
# Training continues.. 136.55187505483627 current i =  272
# Training continues.. 136.88861525058746 current i =  273
# Training continues.. 137.2365236878395 current i =  274
# Training continues.. 137.63446661829948 current i =  275
# Training continues.. 138.0385835468769 current i =  276
# Training continues.. 138.32042530179024 current i =  277
# Training continues.. 138.78631806373596 current i =  278
# Training continues.. 139.0878730416298 current i =  279
# Training continues.. 139.33045062422752 current i =  280
# Training continues.. 139.8092924952507 current i =  281
# Training continues.. 140.33599174022675 current i =  282
# Training continues.. 140.84099584817886 current i =  283
# Training continues.. 141.20848101377487 current i =  284
# Training continues.. 141.59299179911613 current i =  285
# Training continues.. 141.81872929632664 current i =  286
# Training continues.. 142.14227996766567 current i =  287
# Training continues.. 142.5473086386919 current i =  288
# Training continues.. 142.87351329624653 current i =  289
# Training continues.. 143.46637912094593 current i =  290
# Training continues.. 143.86715285480022 current i =  291
# Training continues.. 144.2617917507887 current i =  292
# Training continues.. 144.62985648214817 current i =  293
# Training continues.. 145.06808073818684 current i =  294
# Training continues.. 145.33242954313755 current i =  295
# Training continues.. 145.58845330774784 current i =  296
# Training continues.. 146.05623887479305 current i =  297
# Training continues.. 146.43142281472683 current i =  298
# Training continues.. 146.7605633288622 current i =  299
# Training continues.. 147.3607573658228 current i =  300
# Training continues.. 147.87373138964176 current i =  301
# Training continues.. 148.29165168106556 current i =  302
# Training continues.. 148.7482181340456 current i =  303
# Training continues.. 149.09693364799023 current i =  304
# Training continues.. 149.5275201946497 current i =  305
# Training continues.. 149.93106330931187 current i =  306
# Training continues.. 150.19846971333027 current i =  307
# Training continues.. 150.69548653066158 current i =  308
# Training continues.. 151.02689157426357 current i =  309
# Training continues.. 151.40604166686535 current i =  310
# Training continues.. 151.87377168238163 current i =  311
# Training continues.. 152.4789885431528 current i =  312
# Training continues.. 153.02837593853474 current i =  313
# Training continues.. 153.5709417015314 current i =  314
# Training continues.. 153.97678042948246 current i =  315
# Training continues.. 154.39279247820377 current i =  316
# Training continues.. 154.6781309992075 current i =  317
# Training continues.. 155.0430408269167 current i =  318
# Training continues.. 155.30287657678127 current i =  319
# Training continues.. 155.58312027156353 current i =  320
# Training continues.. 155.93159575760365 current i =  321
# Training continues.. 156.13978607952595 current i =  322
# Training continues.. 156.68568660318851 current i =  323
# Training continues.. 156.93517553806305 current i =  324
# Training continues.. 157.28145515918732 current i =  325
# Training continues.. 157.57500937581062 current i =  326
# Training continues.. 157.99418371915817 current i =  327
# Training continues.. 158.2543105185032 current i =  328
# Training continues.. 158.6419416666031 current i =  329
# Training continues.. 159.0388693511486 current i =  330
# Training continues.. 159.41070026159286 current i =  331
# Training continues.. 159.70075568556786 current i =  332
# Training continues.. 160.20783892273903 current i =  333
# Training continues.. 160.64240217208862 current i =  334
# Training continues.. 160.91939881443977 current i =  335
# Training continues.. 161.15150025486946 current i =  336
# Training continues.. 161.47894337773323 current i =  337
# Training continues.. 161.7054866552353 current i =  338
# Training continues.. 162.09438729286194 current i =  339
# Training continues.. 162.46033105254173 current i =  340
# Training continues.. 162.83379012346268 current i =  341
# Training continues.. 163.10865950584412 current i =  342
# Training continues.. 163.50918570160866 current i =  343
# Training continues.. 163.8660199046135 current i =  344
# Training continues.. 164.33346098661423 current i =  345
# Training continues.. 164.58965158462524 current i =  346
# Training continues.. 164.88978704810143 current i =  347
# Training continues.. 165.22347828745842 current i =  348
# Training continues.. 165.4502251446247 current i =  349
# Training continues.. 165.7689569890499 current i =  350
# Training continues.. 166.20775628089905 current i =  351
# Training continues.. 166.55551168322563 current i =  352
# Training continues.. 166.85794758796692 current i =  353
# Training continues.. 167.16692593693733 current i =  354
# Training continues.. 167.55496364831924 current i =  355
# Training continues.. 167.8923527598381 current i =  356
# Training continues.. 168.11636140942574 current i =  357
# Training continues.. 168.327951207757 current i =  358
# Training continues.. 168.57392477989197 current i =  359
# Training continues.. 169.0454847216606 current i =  360
# Training continues.. 169.43899676203728 current i =  361
# Training continues.. 169.7824985086918 current i =  362
# Training continues.. 170.24552205204964 current i =  363
# Training continues.. 170.60231897234917 current i =  364
# Training continues.. 170.88507282733917 current i =  365
# Training continues.. 171.07451730966568 current i =  366
# Training continues.. 171.29620280861855 current i =  367
# Training continues.. 171.6477279663086 current i =  368
# Training continues.. 171.87743411958218 current i =  369
# Training continues.. 172.23293574154377 current i =  370
# Training continues.. 172.63215158879757 current i =  371
# Training continues.. 172.89146776497364 current i =  372
# Iteration 1 - Loss = 0.4655208310052272
# Training continues.. 0.0 current i =  1
# Training continues.. 0.4144386351108551 current i =  2
# Training continues.. 0.5976619273424149 current i =  3
# Training continues.. 0.9036467224359512 current i =  4
# Training continues.. 1.251486673951149 current i =  5
# Training continues.. 1.541182056069374 current i =  6
# Training continues.. 1.8517541736364365 current i =  7
# Training continues.. 2.2417575269937515 current i =  8
# Training continues.. 2.591347947716713 current i =  9
# Training continues.. 2.8953486531972885 current i =  10
# Training continues.. 3.2291426807641983 current i =  11
# Training continues.. 3.58127324283123 current i =  12
# Training continues.. 3.8054899871349335 current i =  13
# Training continues.. 4.073722541332245 current i =  14
# Training continues.. 4.241684332489967 current i =  15
# Training continues.. 4.638555124402046 current i =  16
# Training continues.. 4.949575796723366 current i =  17
# Training continues.. 5.3288742154836655 current i =  18
# Training continues.. 5.770597472786903 current i =  19
# Training continues.. 6.046735569834709 current i =  20
# Training continues.. 6.393507346510887 current i =  21
# Training continues.. 6.563494101166725 current i =  22
# Training continues.. 6.7681673020124435 current i =  23
# Training continues.. 7.008494392037392 current i =  24
# Training continues.. 7.2370264530181885 current i =  25
# Training continues.. 7.610627472400665 current i =  26
# Training continues.. 7.783830091357231 current i =  27
# Training continues.. 8.163601443171501 current i =  28
# Training continues.. 8.485363021492958 current i =  29
# Training continues.. 8.841669097542763 current i =  30
# Training continues.. 9.314887151122093 current i =  31
# Training continues.. 9.744214788079262 current i =  32
# Training continues.. 10.047345325350761 current i =  33
# Training continues.. 10.489671751856804 current i =  34
# Training continues.. 10.705434113740921 current i =  35
# Training continues.. 10.911893591284752 current i =  36
# Training continues.. 11.271151825785637 current i =  37
# Training continues.. 11.662434116005898 current i =  38
# Training continues.. 11.862387835979462 current i =  39
# Training continues.. 12.196712166070938 current i =  40
# Training continues.. 12.501506000757217 current i =  41
# Training continues.. 12.804119378328323 current i =  42
# Training continues.. 12.956485122442245 current i =  43
# Training continues.. 13.132890492677689 current i =  44
# Training continues.. 13.36125685274601 current i =  45
# Training continues.. 13.593473449349403 current i =  46
# Training continues.. 13.784176990389824 current i =  47
# Training continues.. 13.987753629684448 current i =  48
# Training continues.. 14.29643028974533 current i =  49
# Training continues.. 14.448591902852058 current i =  50
# Training continues.. 14.590926110744476 current i =  51
# Training continues.. 14.820189163088799 current i =  52
# Training continues.. 15.151435449719429 current i =  53
# Training continues.. 15.514074876904488 current i =  54
# Training continues.. 15.698186784982681 current i =  55
# Training continues.. 15.779671713709831 current i =  56
# Training continues.. 15.927464425563812 current i =  57
# Training continues.. 16.03190553933382 current i =  58
# Training continues.. 16.219725631177425 current i =  59
# Training continues.. 16.382136829197407 current i =  60
# Training continues.. 16.728022880852222 current i =  61
# Training continues.. 16.98449093848467 current i =  62
# Training continues.. 17.25156945735216 current i =  63
# Training continues.. 17.6477128341794 current i =  64
# Training continues.. 17.858402140438557 current i =  65
# Training continues.. 18.171157516539097 current i =  66
# Training continues.. 18.51349277049303 current i =  67
# Training continues.. 18.88294855505228 current i =  68
# Training continues.. 19.176630325615406 current i =  69
# Training continues.. 19.38004993647337 current i =  70
# Training continues.. 19.61444728821516 current i =  71
# Training continues.. 19.808075569570065 current i =  72
# Training continues.. 20.11235248297453 current i =  73
# Training continues.. 20.34587586671114 current i =  74
# Training continues.. 20.47747891396284 current i =  75
# Training continues.. 20.71543128043413 current i =  76
# Training continues.. 20.94006422907114 current i =  77
# Training continues.. 21.274488247931004 current i =  78
# Training continues.. 21.520644955337048 current i =  79
# Training continues.. 21.78448062390089 current i =  80
# Training continues.. 21.97601606696844 current i =  81
# Training continues.. 22.27044539898634 current i =  82
# Training continues.. 22.458110593259335 current i =  83
# Training continues.. 22.80628725141287 current i =  84
# Training continues.. 23.045515529811382 current i =  85
# Training continues.. 23.26749838143587 current i =  86
# Training continues.. 23.604200966656208 current i =  87
# Training continues.. 23.83658228069544 current i =  88
# Training continues.. 24.13195053488016 current i =  89
# Training continues.. 24.432253934442997 current i =  90
# Training continues.. 24.606231801211834 current i =  91
# Training continues.. 24.922778449952602 current i =  92
# Training continues.. 25.068009190261364 current i =  93
# Training continues.. 25.30372431129217 current i =  94
# Training continues.. 25.422148570418358 current i =  95
# Training continues.. 25.6272554397583 current i =  96
# Training continues.. 25.777271419763565 current i =  97
# Training continues.. 26.102128118276596 current i =  98
# Training continues.. 26.45289859175682 current i =  99
# Training continues.. 26.692444786429405 current i =  100
# Training continues.. 26.940911442041397 current i =  101
# Training continues.. 27.216234743595123 current i =  102
# Training continues.. 27.616439551115036 current i =  103
# Training continues.. 27.958692282438278 current i =  104
# Training continues.. 28.253041833639145 current i =  105
# Training continues.. 28.580010056495667 current i =  106
# Training continues.. 28.982527673244476 current i =  107
# Training continues.. 29.260680943727493 current i =  108
# Training continues.. 29.489513143897057 current i =  109
# Training continues.. 29.688130915164948 current i =  110
# ...
# Training continues.. 7.759932153858244 current i =  132
# Training continues.. 7.788835764862597 current i =  133
# Training continues.. 7.832155902869999 current i =  134
# Training continues.. 7.849315053783357 current i =  135
# Training continues.. 7.863178036175668 current i =  136
# Training continues.. 8.074444613419473 current i =  137
# Training continues.. 8.170863165520132 current i =  138
# Training continues.. 8.240115753374994 current i =  139
# Training continues.. 8.268406859599054 current i =  140
# Training continues.. 8.345925427041948 current i =  141
# Training continues.. 8.381255111657083 current i =  142
# Training continues.. 8.443734510801733 current i =  143
# Training continues.. 8.499647236429155 current i =  144
# Training continues.. 8.562758005224168 current i =  145
# Training continues.. 8.572061499580741 current i =  146
# Training continues.. 8.671655056998134 current i =  147
# Training continues.. 8.726735642179847 current i =  148
# Training continues.. 8.73644947540015 current i =  149
# Training continues.. 8.767050259746611 current i =  150
# Training continues.. 8.877314575947821 current i =  151
# Training continues.. 8.89007799141109 current i =  152
# Training continues.. 8.94604884274304 current i =  153
# Training continues.. 9.053849348798394 current i =  154
# Training continues.. 9.136565500870347 current i =  155
# Training continues.. 9.152108899317682 current i =  156
# Training continues.. 9.170953485183418 current i =  157
# Training continues.. 9.228098331950605 current i =  158
# Training continues.. 9.236296899616718 current i =  159
# Training continues.. 9.25442961230874 current i =  160
# Training continues.. 9.307579819113016 current i =  161
# Training continues.. 9.43890941515565 current i =  162
# Training continues.. 9.523797016590834 current i =  163
# Training continues.. 9.58659190312028 current i =  164
# Training continues.. 9.601764154620469 current i =  165
# Training continues.. 9.712609310634434 current i =  166
# Training continues.. 9.805109073407948 current i =  167
# Training continues.. 9.932224278338253 current i =  168
# Training continues.. 9.949689156375825 current i =  169
# Training continues.. 9.970240303315222 current i =  170
# Training continues.. 9.995449458248913 current i =  171
# Training continues.. 10.01984193827957 current i =  172
# Training continues.. 10.064316521398723 current i =  173
# Training continues.. 10.125655855052173 current i =  174
# Training continues.. 10.155512514524162 current i =  175
# Training continues.. 10.246804433874786 current i =  176
# Training continues.. 10.287816378287971 current i =  177
# Training continues.. 10.340794201008976 current i =  178
# Training continues.. 10.43884866964072 current i =  179
# Training continues.. 10.496436453424394 current i =  180
# Training continues.. 10.513769838027656 current i =  181
# Training continues.. 10.580277684144676 current i =  182
# Training continues.. 10.654419648461044 current i =  183
# Training continues.. 10.65890249563381 current i =  184
# Training continues.. 10.795389800798148 current i =  185
# Training continues.. 11.071834682952613 current i =  186
# Training continues.. 11.13406641362235 current i =  187
# Training continues.. 11.21130159823224 current i =  188
# Training continues.. 11.407664659898728 current i =  189
# Training continues.. 11.560159015934914 current i =  190
# Training continues.. 11.797932791989297 current i =  191
# Training continues.. 11.852777648251504 current i =  192
# Training continues.. 11.941053296905011 current i =  193
# Training continues.. 12.035048361402005 current i =  194
# Training continues.. 12.092915325891227 current i =  195
# Training continues.. 12.134564898442477 current i =  196
# Training continues.. 12.215563669335097 current i =  197
# Training continues.. 12.29970571352169 current i =  198
# Training continues.. 12.350403800141066 current i =  199
# Training continues.. 12.383271187078208 current i =  200
# Training continues.. 12.430196057539433 current i =  201
# Training continues.. 12.528793822508305 current i =  202
# Training continues.. 12.593178618233651 current i =  203
# Training continues.. 12.717173803132027 current i =  204
# Training continues.. 12.740290034096688 current i =  205
# Training continues.. 12.811302687507123 current i =  206
# Training continues.. 12.863578181248158 current i =  207
# Training continues.. 13.039600010495633 current i =  208
# Training continues.. 13.135818484704942 current i =  209
# Training continues.. 13.236590679269284 current i =  210
# Training continues.. 13.360815058927983 current i =  211
# Training continues.. 13.375200759153813 current i =  212
# Training continues.. 13.455283138435334 current i =  213
# Training continues.. 13.502043187152594 current i =  214
# Training continues.. 13.651629462372512 current i =  215
# Training continues.. 13.725795618724078 current i =  216
# Training continues.. 13.754861963447183 current i =  217
# Training continues.. 13.795411506202072 current i =  218
# Training continues.. 13.81271699955687 current i =  219
# Training continues.. 13.82623195135966 current i =  220
# Training continues.. 13.95916465902701 current i =  221
# Training continues.. 14.099172378424555 current i =  222
# Training continues.. 14.13945064553991 current i =  223
# Training continues.. 14.195591850671917 current i =  224
# Training continues.. 14.210532036144286 current i =  225
# Training continues.. 14.232524166349322 current i =  226
# Training continues.. 14.246683075558394 current i =  227
# Training continues.. 14.264481609221548 current i =  228
# Training continues.. 14.30595709523186 current i =  229
# Training continues.. 14.399658331181854 current i =  230
# Training continues.. 14.51179895689711 current i =  231
# Training continues.. 14.56558666890487 current i =  232
# Training continues.. 14.60980170732364 current i =  233
# Training continues.. 14.682512087281793 current i =  234
# Training continues.. 14.708185139577836 current i =  235
# Training continues.. 14.728047899436206 current i =  236
# Training continues.. 14.742583759594709 current i =  237
# Training continues.. 14.771430999506265 current i =  238
# Training continues.. 14.802641513291746 current i =  239
# Training continues.. 14.83031850727275 current i =  240
# Training continues.. 14.866880119312555 current i =  241
# Training continues.. 14.87868662038818 current i =  242
# Training continues.. 14.909387633670121 current i =  243
# Training continues.. 14.912709362572059 current i =  244
# Training continues.. 14.962642542785034 current i =  245
# Training continues.. 14.99391046888195 current i =  246
# Training continues.. 15.083091422682628 current i =  247
# Training continues.. 15.130243349587545 current i =  248
# Training continues.. 15.168289579218253 current i =  249
# Training continues.. 15.298337839310989 current i =  250
# Training continues.. 15.52012426382862 current i =  251
# Training continues.. 15.554436024045572 current i =  252
# Training continues.. 15.579938363051042 current i =  253
# Training continues.. 15.618112161522731 current i =  254
# Training continues.. 15.627215442014858 current i =  255
# Training continues.. 15.653272882802412 current i =  256
# Training continues.. 15.752704658312723 current i =  257
# Training continues.. 15.806596466107294 current i =  258
# Training continues.. 15.835088240681216 current i =  259
# Training continues.. 15.895554250804707 current i =  260
# Training continues.. 15.964030085830018 current i =  261
# Training continues.. 15.977973677916452 current i =  262
# Training continues.. 16.067613781196997 current i =  263
# Training continues.. 16.282992333872244 current i =  264
# Training continues.. 16.423572540981695 current i =  265
# Training continues.. 16.820629716617987 current i =  266
# Training continues.. 17.003632337553427 current i =  267
# Training continues.. 17.22758323024027 current i =  268
# Training continues.. 17.281550132436678 current i =  269
# Training continues.. 17.432128169341013 current i =  270
# Training continues.. 17.507697568042204 current i =  271
# Training continues.. 17.513299287995324 current i =  272
# Training continues.. 17.56540840282105 current i =  273
# Training continues.. 17.79721967293881 current i =  274
# Training continues.. 17.8472706170287 current i =  275
# Training continues.. 17.902725456049666 current i =  276
# Training continues.. 18.001165663590655 current i =  277
# Training continues.. 18.019046509405598 current i =  278
# Training continues.. 18.09969119145535 current i =  279
# Training continues.. 18.13961880817078 current i =  280
# Training continues.. 18.176472751190886 current i =  281
# Training continues.. 18.283485812833533 current i =  282
# Training continues.. 18.360661102226004 current i =  283
# Training continues.. 18.528184784343466 current i =  284
# Training continues.. 18.683407498290762 current i =  285
# Training continues.. 18.81552012055181 current i =  286
# Training continues.. 18.847882548114285 current i =  287
# Training continues.. 18.874739119550213 current i =  288
# Training continues.. 18.901568656554446 current i =  289
# Training continues.. 18.986293798079714 current i =  290
# Training continues.. 19.035515101393685 current i =  291
# Training continues.. 19.21184909506701 current i =  292
# Training continues.. 19.24852247699164 current i =  293
# Training continues.. 19.39281112118624 current i =  294
# Training continues.. 19.49303095205687 current i =  295
# Training continues.. 19.544377909740433 current i =  296
# Training continues.. 19.58449632464908 current i =  297
# Training continues.. 19.61059403582476 current i =  298
# Training continues.. 19.70331254019402 current i =  299
# Training continues.. 19.728191461181268 current i =  300
# Training continues.. 19.779387693619356 current i =  301
# Training continues.. 19.834463387494907 current i =  302
# Training continues.. 19.865636924048886 current i =  303
# Training continues.. 19.87497606384568 current i =  304
# Training continues.. 19.904148497385904 current i =  305
# Training continues.. 19.92517849127762 current i =  306
# Training continues.. 20.073501446051523 current i =  307
# Training continues.. 20.210121222538874 current i =  308
# Training continues.. 20.242954809917137 current i =  309
# Training continues.. 20.333976019872352 current i =  310
# Training continues.. 20.346148961922154 current i =  311
# Training continues.. 20.405390525003895 current i =  312
# Training continues.. 20.447965638479218 current i =  313
# Training continues.. 20.45934969908558 current i =  314
# Training continues.. 20.535386986797675 current i =  315
# Training continues.. 20.641183413332328 current i =  316
# Training continues.. 20.709942415123805 current i =  317
# Training continues.. 20.799756839638576 current i =  318
# Training continues.. 20.879022627836093 current i =  319
# Training continues.. 20.954775117104873 current i =  320
# Training continues.. 21.009152821963653 current i =  321
# Training continues.. 21.068655173992738 current i =  322
# Training continues.. 21.082721538608894 current i =  323
# Training continues.. 21.09468051395379 current i =  324
# Training continues.. 21.13222324452363 current i =  325
# Training continues.. 21.184007599717006 current i =  326
# Training continues.. 21.254579111700878 current i =  327
# Training continues.. 21.31664380407892 current i =  328
# Training continues.. 21.35721782199107 current i =  329
# Training continues.. 21.369209671160206 current i =  330
# Training continues.. 21.38240054040216 current i =  331
# Training continues.. 21.39201129018329 current i =  332
# Training continues.. 21.45692224591039 current i =  333
# Training continues.. 21.484907570993528 current i =  334
# Training continues.. 21.597038630163297 current i =  335
# Training continues.. 21.605446920497343 current i =  336
# Training continues.. 21.669425279600546 current i =  337
# Training continues.. 21.76550351898186 current i =  338
# Training continues.. 21.799254291458055 current i =  339
# Training continues.. 21.856953867478296 current i =  340
# Training continues.. 21.877423519967124 current i =  341
# Training continues.. 21.919846343575045 current i =  342
# Training continues.. 21.95831316220574 current i =  343
# Training continues.. 22.008680320112035 current i =  344
# Training continues.. 22.01890587876551 current i =  345
# Training continues.. 22.029456155141816 current i =  346
# Training continues.. 22.05101174651645 current i =  347
# Training continues.. 22.094815088203177 current i =  348
# Training continues.. 22.14370827912353 current i =  349
# Training continues.. 22.165281794732437 current i =  350
# Training continues.. 22.172985561890528 current i =  351
# Training continues.. 22.21748545090668 current i =  352
# Training continues.. 22.317279645008966 current i =  353
# Training continues.. 22.40220429818146 current i =  354
# Training continues.. 22.421555547742173 current i =  355
# Training continues.. 22.502582034794614 current i =  356
# Training continues.. 22.53183941799216 current i =  357
# Training continues.. 22.573299451498315 current i =  358
# Training continues.. 22.614441535202786 current i =  359
# Training continues.. 22.639970157993957 current i =  360
# Training continues.. 22.676351458532736 current i =  361
# Training continues.. 22.682176919886842 current i =  362
# Training continues.. 22.749116914579645 current i =  363
# Training continues.. 22.813531214604154 current i =  364
# Training continues.. 22.81600771099329 current i =  365
# Training continues.. 22.848672907799482 current i =  366
# Training continues.. 22.897813264280558 current i =  367
# Training continues.. 22.906234920024872 current i =  368
# Training continues.. 22.921334614045918 current i =  369
# Training continues.. 23.03165822196752 current i =  370
# Training continues.. 23.10563771147281 current i =  371
# Training continues.. 23.291185510344803 current i =  372
# Iteration 5 - Loss = 0.06274749617272567
# Training continues.. 0.0 current i =  1
# Training continues.. 0.044158462435007095 current i =  2
# Training continues.. 0.1027444340288639 current i =  3
# Training continues.. 0.16778621450066566 current i =  4
# Training continues.. 0.20242832601070404 current i =  5
# Training continues.. 0.3873787820339203 current i =  6
# Training continues.. 0.5094698518514633 current i =  7
# Training continues.. 0.5796597525477409 current i =  8
# Training continues.. 0.7403318509459496 current i =  9
# Training continues.. 0.8027577362954617 current i =  10
# Training continues.. 1.2341479323804379 current i =  11
# Training continues.. 1.613889779895544 current i =  12
# Training continues.. 1.8309729062020779 current i =  13
# Training continues.. 1.8692015036940575 current i =  14
# Training continues.. 2.0198124274611473 current i =  15
# Training continues.. 2.113602787256241 current i =  16
# Training continues.. 2.141506889835 current i =  17
# Training continues.. 2.2272176761180162 current i =  18
# Training continues.. 2.2634921986609697 current i =  19
# Training continues.. 2.369035506621003 current i =  20
# Training continues.. 2.454633543267846 current i =  21
# Training continues.. 2.567759545519948 current i =  22
# Training continues.. 2.635328257456422 current i =  23
# Training continues.. 2.7595010716468096 current i =  24
# Training continues.. 2.893227519467473 current i =  25
# Training continues.. 2.9870475996285677 current i =  26
# Training continues.. 3.04207600094378 current i =  27
# Training continues.. 3.127640137448907 current i =  28
# Training continues.. 3.169100424274802 current i =  29
# Training continues.. 3.2537906002253294 current i =  30
# Training continues.. 3.3377961721271276 current i =  31
# Training continues.. 3.482731079682708 current i =  32
# Training continues.. 3.540811223909259 current i =  33
# Training continues.. 3.778819380328059 current i =  34
# Training continues.. 3.80783081240952 current i =  35
# Training continues.. 3.8910524789243937 current i =  36
# Training continues.. 3.9189995396882296 current i =  37
# Training continues.. 3.95578988827765 current i =  38
# Training continues.. 4.110134223476052 current i =  39
# Training continues.. 4.168896047398448 current i =  40
# Training continues.. 4.183912833221257 current i =  41
# Training continues.. 4.2691670106723905 current i =  42

# %% [markdown]
# ## Evaluation

# %%
# Validation loop
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for inputs, labels in val_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

validation_accuracy = 100 * correct / total
print(f"Validation Accuracy: {validation_accuracy}%")

# %%
# Testing loop
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total
print(f"Test Accuracy: {test_accuracy}%")
